# %%
#import required modules and packages
from bs4 import BeautifulSoup as bs
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnnotationBbox, OffsetImage
from PIL import Image
from mplsoccer import Pitch, VerticalPitch
from mplsoccer.utils import FontManager
from highlight_text import HighlightText, ax_text, fig_text

# %%
#scrape single game shots
#14651
base_url = 'https://understat.com/match/'
match = str(input("PLease enter a match ID: "))
url = base_url + match

# %%
url
# Out:
# 'https://understat.com/match/14651'

# %%
#scraping all the scripts in the webpage
req = requests.get(url)
soup = bs(req.content,'lxml')
scripts = soup.find_all('script')

# %%
scripts
# Out:
# [<script>
#  			var THEME = localStorage.getItem("theme") || 'DARK';
#  			document.body.className = "theme-" + THEME.toLowerCase();
#  		</script>,
#  <script>
#  	var shotsData 	= JSON.parse('\x7B\x22h\x22\x3A\x5B\x7B\x22id\x22\x3A\x22402468\x22,\x22minute\x22\x3A\x227\x22,\x22result\x22\x3A\x22MissedShots\x22,\x22X\x22\x3A\x220.754000015258789\x22,\x22Y\x22\x3A\x220.6530000305175782\x22,\x22xG\x22\x3A\x220.017538007348775864\x22,\x22player\x22\x3A\x22Fred\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x226817\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222020\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2214651\x22,\x22h_team\x22\x3A\x22Manchester\x20United\x22,\x22a_team\x22\x3A\x22Southampton\x22,\x22h_goals\x22\x3A\x229\x22,\x22a_goals\x22\x3A\x220\x22,\x22date\x22\x3A\x222021\x2D02\x2D02\x2020\x3A15\x3A00\x22,\x22player_assisted\x22\x3A\x22Luke\x20Shaw\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22402469\x22,\x22minute\x22\x3A\x2213\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.8780000305175781\x22,\x22Y\x22\x3A\x220.5520000076293945\x22,\x22xG\x22\x3A\x220.11381208896636963\x22,\x22player\x22\x3A\x22Mason\x20Greenwood\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x227490\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222020\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2214651\x22,\x22h_team\x22\x3A\x22Manchester\x20United\x22,\x22a_team\x22\x3A\x22Southampton\x22,\x22h_goals\x22\x3A\x229\x22,\x22a_goals\x22\x3A\x220\x22,\x22date\x22\x3A\x222021\x2D02\x2D02\x2020\x3A15\x3A00\x22,\x22player_assisted\x22\x3A\x22Luke\x20Shaw\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22402470\x22,\x22minute\x22\x3A\x2215\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.785\x22,\x22Y\x22\x3A\x220.7169999694824218\x22,\x22xG\x22\x3A\x220.018008871003985405\x22,\x22player\x22\x3A\x22Marcus\x20Rashford\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x22556\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222020\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2214651\x22,\x22h_team\x22\x3A\x22Manchester\x20United\x22,\x22a_team\x22\x3A\x22Southampton\x22,\x22h_goals\x22\x3A\x229\x22,\x22a_goals\x22\x3A\x220\x22,\x22date\x22\x3A\x222021\x2D02\x2D02\x2020\x3A15\x3A00\x22,\x22player_assisted\x22\x3A\x22Luke\x20Shaw\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22402472\x22,\x22minute\x22\x3A\x2217\x22,\x22result\x22\x3A\x22Goal\x22,\x22X\x22\x3A\x220.9680000305175781\x22,\x22Y\x22\x3A\x220.475\x22,\x22xG\x22\x3A\x220.6151849627494812\x22,\x22player\x22\x3A\x22Aaron\x20Wan\x2DBissaka\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x225584\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222020\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2214651\x22,\x22h_team\x22\x3A\x22Manchester\x20United\x22,\x22a_team\x22\x3A\x22Southampton\x22,\x22h_goals\x22\x3A\x229\x22,\x22a_goals\x22\x3A\x220\x22,\x22date\x22\x3A\x222021\x2D02\x2D02\x2020\x3A15\x3A00\x22,\x22player_assisted\x22\x3A\x22Luke\x20Shaw\x22,\x22lastAction\x22\x3A\x22Cross\x22\x7D,\x7B\x22id\x22\x3A\x22402473\x22,\x22minute\x22\x3A\x2224\x22,\x22result\x22\x3A\x22Goal\x22,\x22X\x22\x3A\x220.9080000305175782\x22,\x22Y\x22\x3A\x220.5\x22,\x22xG\x22\x3A\x220.4739765226840973\x22,\x22player\x22\x3A\x22Marcus\x20Rashford\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x22556\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222020\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2214651\x22,\x22h_team\x22\x3A\x22Manchester\x20United\x22,\x22a_team\x22\x3A\x22Southampton\x22,\x22h_goals\x22\x3A\x229\x22,\x22a_goals\x22\x3A\x220\x22,\x22date\x22\x3A\x222021\x2D02\x2D02\x2020\x3A15\x3A00\x22,\x22player_assisted\x22\x3A\x22Mason\x20Greenwood\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22402475\x22,\x22minute\x22\x3A\x2230\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.7930000305175782\x22,\x22Y\x22\x3A\x220.6959999847412109\x22,\x22xG\x22\x3A\x220.020623087882995605\x22,\x22player\ ...
#  		match_info 	= JSON.parse('\x7B\x22id\x22\x3A\x2214651\x22,\x22fid\x22\x3A\x221485357\x22,\x22h\x22\x3A\x2289\x22,\x22a\x22\x3A\x2274\x22,\x22date\x22\x3A\x222021\x2D02\x2D02\x2020\x3A15\x3A00\x22,\x22league_id\x22\x3A\x221\x22,\x22season\x22\x3A\x222020\x22,\x22h_goals\x22\x3A\x229\x22,\x22a_goals\x22\x3A\x220\x22,\x22team_h\x22\x3A\x22Manchester\x20United\x22,\x22team_a\x22\x3A\x22Southampton\x22,\x22h_xg\x22\x3A\x225.0325\x22,\x22a_xg\x22\x3A\x220.507893\x22,\x22h_w\x22\x3A\x220.9916\x22,\x22h_d\x22\x3A\x220.0075\x22,\x22h_l\x22\x3A\x220.0009\x22,\x22league\x22\x3A\x22EPL\x22,\x22h_shot\x22\x3A\x2224\x22,\x22a_shot\x22\x3A\x223\x22,\x22h_shotOnTarget\x22\x3A\x2214\x22,\x22a_shotOnTarget\x22\x3A\x221\x22,\x22h_deep\x22\x3A\x2223\x22,\x22a_deep\x22\x3A\x222\x22,\x22a_ppda\x22\x3A\x2214.5000\x22,\x22h_ppda\x22\x3A\x224.5556\x22\x7D');
#  </script>,
#  <script>
#  	var rostersData	= JSON.parse('\x7B\x22h\x22\x3A\x7B\x22446739\x22\x3A\x7B\x22id\x22\x3A\x22446739\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x22546\x22,\x22team_id\x22\x3A\x2289\x22,\x22position\x22\x3A\x22GK\x22,\x22player\x22\x3A\x22David\x20de\x20Gea\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.9621796607971191\x22,\x22xGBuildup\x22\x3A\x220.9621796607971191\x22,\x22positionOrder\x22\x3A\x221\x22\x7D,\x22446740\x22\x3A\x7B\x22id\x22\x3A\x22446740\x22,\x22goals\x22\x3A\x221\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x221\x22,\x22xG\x22\x3A\x220.6151849627494812\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x225584\x22,\x22team_id\x22\x3A\x2289\x22,\x22position\x22\x3A\x22DR\x22,\x22player\x22\x3A\x22Aaron\x20Wan\x2DBissaka\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x222.19362473487854\x22,\x22xGBuildup\x22\x3A\x221.5784398317337036\x22,\x22positionOrder\x22\x3A\x222\x22\x7D,\x22446741\x22\x3A\x7B\x22id\x22\x3A\x22446741\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x226080\x22,\x22team_id\x22\x3A\x2289\x22,\x22position\x22\x3A\x22DC\x22,\x22player\x22\x3A\x22Victor\x20Lindel\x5Cu00f6f\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x221\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220.055975291877985\x22,\x22xGChain\x22\x3A\x222.2482407093048096\x22,\x22xGBuildup\x22\x3A\x222.2482407093048096\x22,\x22positionOrder\x22\x3A\x223\x22\x7D,\x22446742\x22\x3A\x7B\x22id\x22\x3A\x22446742\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x221687\x22,\x22team_id\x22\x3A\x2289\x22,\x22position\x22\x3A\x22DC\x22,\x22player\x22\x3A\x22Harry\x20Maguire\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x221\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x221.7448463439941406\x22,\x22xGBuildup\x22\x3A\x221.7448463439941406\x22,\x22positionOrder\x22\x3A\x223\x22\x7D,\x22446743\x22\x3A\x7B\x22id\x22\x3A\x22446743\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x221\x22,\x22xG\x22\x3A\x220.019085945561528206\x22,\x22time\x22\x3A\x2248\x22,\x22player_id\x22\x3A\x221006\x22,\x22team_id\x22\x3A\x2289\x22,\x22position\x22\x3A\x22DL\x22,\x22player\x22\x3A\x22Luke\x20Shaw\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x22446751\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x225\x22,\x22assists\x22\x3A\x222\x22,\x22xA\x22\x3A\x221.1466081142425537\x22,\x22xGChain\x22\x3A\x221.6871092319488525\x22,\x22xGBuildup\x22\x3A\x221.1736948490142822\x22,\x22positionOrder\x22\x3A\x224\x22\x7D,\x22446744\x22\x3A\x7B\x22id\x22\x3A\x22446744\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x222\x22,\x22xG\x22\x3A\x220.048556942492723465\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x226817\x22,\x22team_id\x22\x3A\x2289\x22,\x22position\x22\x3A\x22DMC\x22,\x22player\x22\x3A\x22Fred\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22, ...
#  </script>,
#  <script defer="" src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript"></script>,
#  <script src="//ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script>,
#  <script>
#  		WebFont.load({
#  			google: {
#  				families: ['Barlow:500', 'Anton']
#  			},
#  			active: function(){
#  				flagFontsLoading = true;
#  			}
#  		});
#  		var BASE_URL = 'https://understat.com/',
#  			PROMOTION =  JSON.parse('\x7B\x22id\x22\x3A\x227\x22,\x22name\x22\x3A\x22adsense\x22,\x22template\x22\x3A\x22\x3Cins\x20class\x3D\x5C\x22adsbygoogle\x5C\x22\x20style\x3D\x5C\x22display\x3Ablock\x5C\x22\x20data\x2Dad\x2Dclient\x3D\x5C\x22ca\x2Dpub\x2D7470116180195095\x5C\x22\x20data\x2Dad\x2Dslot\x3D\x5C\x222199699885\x5C\x22\x20data\x2Dad\x2Dformat\x3D\x5C\x22auto\x5C\x22\x20data\x2Dfull\x2Dwidth\x2Dresponsive\x3D\x5C\x22true\x5C\x22\x3E\x3C\x5C\x2Fins\x3E\x22,\x22js\x22\x3A\x22\x28adsbygoogle\x20\x3D\x20window.adsbygoogle\x20\x7C\x7C\x20\x5B\x5D\x29.push\x28\x7B\x7D\x29\x3B\x22,\x22countries_list_type\x22\x3A\x22black\x22,\x22clicks\x22\x3A\x223618\x22\x7D') ;
#  	</script>,
#  <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>,
#  <script defer="" src="//code.jquery.com/jquery-1.12.4.js" type="text/javascript"></script>,
#  <script defer="" src="//code.jquery.com/ui/1.12.1/jquery-ui.js" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.iframetracker.min.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/Chart.js/2.7.2/Chart.min.js" type="text/javascript"></script>,
#  <script defer="" src="js/timsort.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/tooltip.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/pagination.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/select.js?v=2.1" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.mousewheel.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/modernizr.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/simplebar.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/typeahead.bundle.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/jTable.js?v=2.6" type="text/javascript"></script>,
#  <script defer="" src="js/main.js?v=2.9" type="text/javascript"></script>,
#  <script>
#  		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#  		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#  		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#  		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#  		ga('create', 'UA-101482034-1', 'auto');
#  		ga('send', 'pageview');
#
#  					window.onload = function() { (adsbygoogle = window.adsbygoogle || []).push({}); }
#  			</script>,
#  <script defer="" src="js/match.js?v=2.1" type="text/javascript"></script>]

# %%
#get only shot data script
strings = scripts[1].string

# %%
strings
# Out:
# "\n\tvar shotsData \t= JSON.parse('\\x7B\\x22h\\x22\\x3A\\x5B\\x7B\\x22id\\x22\\x3A\\x22402468\\x22,\\x22minute\\x22\\x3A\\x227\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.754000015258789\\x22,\\x22Y\\x22\\x3A\\x220.6530000305175782\\x22,\\x22xG\\x22\\x3A\\x220.017538007348775864\\x22,\\x22player\\x22\\x3A\\x22Fred\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x226817\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222020\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2214651\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20United\\x22,\\x22a_team\\x22\\x3A\\x22Southampton\\x22,\\x22h_goals\\x22\\x3A\\x229\\x22,\\x22a_goals\\x22\\x3A\\x220\\x22,\\x22date\\x22\\x3A\\x222021\\x2D02\\x2D02\\x2020\\x3A15\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Luke\\x20Shaw\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22402469\\x22,\\x22minute\\x22\\x3A\\x2213\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.8780000305175781\\x22,\\x22Y\\x22\\x3A\\x220.5520000076293945\\x22,\\x22xG\\x22\\x3A\\x220.11381208896636963\\x22,\\x22player\\x22\\x3A\\x22Mason\\x20Greenwood\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x227490\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222020\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2214651\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20United\\x22,\\x22a_team\\x22\\x3A\\x22Southampton\\x22,\\x22h_goals\\x22\\x3A\\x229\\x22,\\x22a_goals\\x22\\x3A\\x220\\x22,\\x22date\\x22\\x3A\\x222021\\x2D02\\x2D02\\x2020\\x3A15\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Luke\\x20Shaw\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22402470\\x22,\\x22minute\\x22\\x3A\\x2215\\x22,\\x22result\\x22\\x3A\\x22SavedShot\\x22,\\x22X\\x22\\x3A\\x220.785\\x22,\\x22Y\\x22\\x3A\\x220.7169999694824218\\x22,\\x22xG\\x22\\x3A\\x220.018008871003985405\\x22,\\x22player\\x22\\x3A\\x22Marcus\\x20Rashford\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22556\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222020\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2214651\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20United\\x22,\\x22a_team\\x22\\x3A\\x22Southampton\\x22,\\x22h_goals\\x22\\x3A\\x229\\x22,\\x22a_goals\\x22\\x3A\\x220\\x22,\\x22date\\x22\\x3A\\x222021\\x2D02\\x2D02\\x2020\\x3A15\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Luke\\x20Shaw\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22402472\\x22,\\x22minute\\x22\\x3A\\x2217\\x22,\\x22result\\x22\\x3A\\x22Goal\\x22,\\x22X\\x22\\x3A\\x220.9680000305175781\\x22,\\x22Y\\x22\\x3A\\x220.475\\x22,\\x22xG\\x22\\x3A\\x220.6151849627494812\\x22,\\x22player\\x22\\x3A\\x22Aaron\\x20Wan\\x2DBissaka\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x225584\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222020\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2214651\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20United\\x22,\\x22a_team\\x22\\x3A\\x22Southampton\\x22,\\x22h_goals\\x22\\x3A\\x229\\x22,\\x22a_goals\\x22\\x3A\\x220\\x22,\\x22date\\x22\\x3A\\x222021\\x2D02\\x2D02\\x2020\\x3A15\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Luke\\x20Shaw\\x22,\\x22lastAction\\x22\\x3A\\x22Cross\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22402473\\x22,\\x22minute\\x22\\x3A\\x2224\\x22,\\x22result\\x22\\x3A\\x22Goal\\x22,\\x22X\\x22\\x3A\\x220.9080000305175782\\x22,\\x22Y\\x22\\x3A\\x220.5\\x22,\\x22xG\\x22\\x3A\\x220.4739765226840973\\x22,\\x22player\\x22\\x3A\\x22Marcus\\x20Rashford\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22556\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222020\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2214651\\x22,\\x22h_team ...

# %%
#strip data into correct json format
ind_start = strings.index("('")+2
ind_end = strings.index("')")

json_data = strings[ind_start:ind_end]
#encode data
json_data = json_data.encode('utf8').decode('unicode_escape')

#convert string to json format
data = json.loads(json_data)

# %%
data
# Out:
# {'h': [{'id': '402468',
#    'minute': '7',
#    'result': 'MissedShots',
#    'X': '0.754000015258789',
#    'Y': '0.6530000305175782',
#    'xG': '0.017538007348775864',
#    'player': 'Fred',
#    'h_a': 'h',
#    'player_id': '6817',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Luke Shaw',
#    'lastAction': 'Pass'},
#   {'id': '402469',
#    'minute': '13',
#    'result': 'BlockedShot',
#    'X': '0.8780000305175781',
#    'Y': '0.5520000076293945',
#    'xG': '0.11381208896636963',
#    'player': 'Mason Greenwood',
#    'h_a': 'h',
#    'player_id': '7490',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'LeftFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Luke Shaw',
#    'lastAction': 'Pass'},
#   {'id': '402470',
#    'minute': '15',
#    'result': 'SavedShot',
#    'X': '0.785',
#    'Y': '0.7169999694824218',
#    'xG': '0.018008871003985405',
#    'player': 'Marcus Rashford',
#    'h_a': 'h',
#    'player_id': '556',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Luke Shaw',
#    'lastAction': 'Pass'},
#   {'id': '402472',
#    'minute': '17',
#    'result': 'Goal',
#    'X': '0.9680000305175781',
#    'Y': '0.475',
#    'xG': '0.6151849627494812',
#    'player': 'Aaron Wan-Bissaka',
#    'h_a': 'h',
#    'player_id': '5584',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Luke Shaw',
#    'lastAction': 'Cross'},
#   {'id': '402473',
#    'minute': '24',
#    'result': 'Goal',
#    'X': '0.9080000305175782',
#    'Y': '0.5',
#    'xG': '0.4739765226840973',
#    'player': 'Marcus Rashford',
#    'h_a': 'h',
#    'player_id': '556',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Mason Greenwood',
#    'lastAction': 'Pass'},
#   {'id': '402475',
#    'minute': '30',
#    'result': 'SavedShot',
#    'X': '0.7930000305175782',
#    'Y': '0.6959999847412109',
#    'xG': '0.020623087882995605',
#    'player': 'Bruno Fernandes',
#    'h_a': 'h',
#    'player_id': '1228',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Marcus Rashford',
#    'lastAction': 'Pass'},
#   {'id': '402476',
#    'minute': '32',
#    'result': 'SavedShot',
#    'X': '0.8',
#    'Y': '0.675',
#    'xG': '0.019085945561528206',
#    'player': 'Luke Shaw',
#    'h_a': 'h',
#    'player_id': '1006',
#    'situation': 'FromCorner',
#    'season': '2020',
#    'shotType': 'LeftFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '402478',
#    'minute': '35',
#    'result': 'MissedShots',
#    'X': '0.8090000152587891',
#    'Y': '0.445',
#    'xG': '0.06652456521987915',
#    'player': 'Scott McTominay',
#    'h_a': 'h',
#    'player_id': '5560',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Bruno Fernandes',
#    'lastAction': 'Pass'},
#   {'id': '402479',
#    'minute': '38',
#    'result': 'Goal',
#    'X': '0.9159999847412109',
#    'Y': '0.4909999847412109',
#    'xG': '0.38206419348716736',
#    'player': 'Edinson Cavani',
#    'h_a': 'h',
#    'player_id': '3294',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'Head',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Luke Shaw',
#    'lastAction': 'Cross'},
#   {'id': '402480',
#    'minute': '44',
#    'result': 'BlockedShot',
#    'X': '0.8159999847412109',
#    'Y': '0.705',
#    'xG': '0.07536032795906067',
#    'player': 'Bruno Fernandes',
#    'h_a': 'h',
#    'player_id': '1228',
#    'situation': 'DirectFreekick',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '402481',
#    'minute': '50',
#    'result': 'BlockedShot',
#    'X': '0.9359999847412109',
#    'Y': '0.615999984741211',
#    'xG': '0.12266551703214645',
#    'player': 'Anthony Martial',
#    'h_a': 'h',
#    'player_id': '553',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Bruno Fernandes',
#    'lastAction': 'Pass'},
#   {'id': '402482',
#    'minute': '55',
#    'result': 'SavedShot',
#    'X': '0.825',
#    'Y': '0.649000015258789',
#    'xG': '0.051032308489084244',
#    'player': 'Bruno Fernandes',
#    'h_a': 'h',
#    'player_id': '1228',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Fred',
#    'lastAction': 'Pass'},
#   {'id': '402483',
#    'minute': '58',
#    'result': 'BlockedShot',
#    'X': '0.8030000305175782',
#    'Y': '0.515',
#    'xG': '0.0466916486620903',
#    'player': 'Bruno Fernandes',
#    'h_a': 'h',
#    'player_id': '1228',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '402484',
#    'minute': '66',
#    'result': 'BlockedShot',
#    'X': '0.805',
#    'Y': '0.6040000152587891',
#    'xG': '0.0310189351439476',
#    'player': 'Fred',
#    'h_a': 'h',
#    'player_id': '6817',
#    'situation': 'FromCorner',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Bruno Fernandes',
#    'lastAction': 'Cross'},
#   {'id': '402485',
#    'minute': '68',
#    'result': 'Goal',
#    'X': '0.975999984741211',
#    'Y': '0.40099998474121096',
#    'xG': '0.3521619737148285',
#    'player': 'Anthony Martial',
#    'h_a': 'h',
#    'player_id': '553',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Bruno Fernandes',
#    'lastAction': 'Chipped'},
#   {'id': '402486',
#    'minute': '70',
#    'result': 'SavedShot',
#    'X': '0.9219999694824219',
#    'Y': '0.31',
#    'xG': '0.08289285749197006',
#    'player': 'Mason Greenwood',
#    'h_a': 'h',
#    'player_id': '7490',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Scott McTominay',
#    'lastAction': 'Pass'},
#   {'id': '402487',
#    'minute': '70',
#    'result': 'Goal',
#    'X': '0.754000015258789',
#    'Y': '0.45099998474121095',
#    'xG': '0.017095061019062996',
#    'player': 'Scott McTominay',
#    'h_a': 'h',
#    'player_id': '5560',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': None,
#    'lastAction': 'Rebound'},
#   {'id': '402489',
#    'minute': '73',
#    'result': 'MissedShots',
#    'X': '0.8719999694824219',
#    'Y': '0.6990000152587891',
#    'xG': '0.34699469804763794',
#    'player': 'Anthony Martial',
#    'h_a': 'h',
#    'player_id': '553',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Fred',
#    'lastAction': 'Throughball'},
#   {'id': '402490',
#    'minute': '77',
#    'result': 'MissedShots',
#    'X': '0.855999984741211',
#    'Y': '0.6509999847412109',
#    'xG': '0.07398506253957748',
#    'player': 'Bruno Fernandes',
#    'h_a': 'h',
#    'player_id': '1228',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Daniel James',
#    'lastAction': 'BallTouch'},
#   {'id': '402491',
#    'minute': '80',
#    'result': 'SavedShot',
#    'X': '0.8390000152587891',
#    'Y': '0.2989999961853027',
#    'xG': '0.055975291877985',
#    'player': 'Mason Greenwood',
#    'h_a': 'h',
#    'player_id': '7490',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'LeftFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Victor Lindelöf',
#    'lastAction': 'Pass'},
#   {'id': '402492',
#    'minute': '86',
#    'result': 'Goal',
#    'X': '0.885',
#    'Y': '0.5',
#    'xG': '0.7611688375473022',
#    'player': 'Bruno Fernandes',
#    'h_a': 'h',
#    'player_id': '1228',
#    'situation': 'Penalty',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '402493',
#    'minute': '89',
#    'result': 'Goal',
#    'X': '0.9440000152587891',
#    'Y': '0.54',
#    'xG': '0.6101189255714417',
#    'player': 'Anthony Martial',
#    'h_a': 'h',
#    'player_id': '553',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '402494',
#    'minute': '91',
#    'result': 'MissedShots',
#    'X': '0.9159999847412109',
#    'Y': '0.549000015258789',
#    'xG': '0.04576248303055763',
#    'player': 'Anthony Martial',
#    'h_a': 'h',
#    'player_id': '553',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'Head',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Mason Greenwood',
#    'lastAction': 'Aerial'},
#   {'id': '402495',
#    'minute': '92',
#    'result': 'Goal',
#    'X': '0.9590000152587891',
#    'Y': '0.5270000076293946',
#    'xG': '0.634173572063446',
#    'player': 'Daniel James',
#    'h_a': 'h',
#    'player_id': '5595',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Bruno Fernandes',
#    'lastAction': 'HeadPass'}],
#  'a': [{'id': '402471',
#    'minute': '16',
#    'result': 'MissedShots',
#    'X': '0.7280000305175781',
#    'Y': '0.47',
#    'xG': '0.016576746478676796',
#    'player': 'James Ward-Prowse',
#    'h_a': 'a',
#    'player_id': '843',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Che Adams',
#    'lastAction': 'Pass'},
#   {'id': '402474',
#    'minute': '27',
#    'result': 'SavedShot',
#    'X': '0.82',
#    'Y': '0.5670000076293945',
#    'xG': '0.1580093950033188',
#    'player': 'James Ward-Prowse',
#    'h_a': 'a',
#    'player_id': '843',
#    'situation': 'DirectFreekick',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '402477',
#    'minute': '33',
#    'result': 'OwnGoal',
#    'X': '0.051999998092651364',
#    'Y': '0.49',
#    'xG': '0',
#    'player': 'Jan Bednarek',
#    'h_a': 'a',
#    'player_id': '6042',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'LeftFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': None,
#    'lastAction': 'BlockedPass'},
#   {'id': '402488',
#    'minute': '72',
#    'result': 'MissedShots',
#    'X': '0.8830000305175781',
#    'Y': '0.524000015258789',
#    'xG': '0.3333064317703247',
#    'player': 'Che Adams',
#    'h_a': 'a',
#    'player_id': '7700',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'LeftFoot',
#    'match_id': '14651',
#    'h_team': 'Manchester United',
#    'a_team': 'Southampton',
#    'h_goals': '9',
#    'a_goals': '0',
#    'date': '2021-02-02 20:15:00',
#    'player_assisted': 'Nathan Redmond',
#    'lastAction': 'Pass'}]}

# %%
x = []
y = []
xG = []
team = []
result = []
player = []
data_away = data['a']
data_home = data['h']

#loop through each line in home team dictionary
for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'xG':
            xG.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
        if key == 'result':
            result.append(data_home[index][key])
        if key == 'player':
            player.append(data_home[index][key])

#loop through each line in away team dictionary
for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'xG':
            xG.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])
        if key == 'result':
            result.append(data_away[index][key])
        if key == 'player':
            player.append(data_away[index][key])

# %%
#create dataframe
col_names = ['team','player','x','y','xG','result']
shots = pd.DataFrame([team,player,x,y,xG,result],index=col_names)
shots = shots.T

# %%
#convert numerical string to float
shots['x'] = pd.to_numeric(shots['x'])
shots['y'] = pd.to_numeric(shots['y'])
shots['xG'] = pd.to_numeric(shots['xG'])

#adjust coordinate values
shots['x'] = shots['x']*100
shots['y'] = shots['y']*100

shots['xx'] = shots['y']
shots['yy'] = shots['x']

shots['x'] = shots['xx']
shots['y'] = shots['yy']

shots['x'] = shots['x']*.8
shots['y'] = shots['y']*1.2

shots
# Out:
#                  team             player          x           y        xG  \
# 0   Manchester United               Fred  52.240002   90.480002  0.017538
# 1   Manchester United    Mason Greenwood  44.160001  105.360004  0.113812
# 2   Manchester United    Marcus Rashford  57.359998   94.200000  0.018009
# 3   Manchester United  Aaron Wan-Bissaka  38.000000  116.160004  0.615185
# 4   Manchester United    Marcus Rashford  40.000000  108.960004  0.473977
# 5   Manchester United    Bruno Fernandes  55.679999   95.160004  0.020623
# 6   Manchester United          Luke Shaw  54.000000   96.000000  0.019086
# 7   Manchester United    Scott McTominay  35.600000   97.080002  0.066525
# 8   Manchester United     Edinson Cavani  39.279999  109.919998  0.382064
# 9   Manchester United    Bruno Fernandes  56.400000   97.919998  0.075360
# 10  Manchester United    Anthony Martial  49.279999  112.319998  0.122666
# 11  Manchester United    Bruno Fernandes  51.920001   99.000000  0.051032
# 12  Manchester United    Bruno Fernandes  41.200000   96.360004  0.046692
# 13  Manchester United               Fred  48.320001   96.600000  0.031019
# 14  Manchester United    Anthony Martial  32.079999  117.119998  0.352162
# 15  Manchester United    Mason Greenwood  24.800000  110.639996  0.082893
# 16  Manchester United    Scott McTominay  36.079999   90.480002  0.017095
# 17  Manchester United    Anthony Martial  55.920001  104.639996  0.346995
# 18  Manchester United    Bruno Fernandes  52.079999  102.719998  0.073985
# 19  Manchester United    Mason Greenwood  23.920000  100.680002  0.055975
# 20  Manchester United    Bruno Fernandes  40.000000  106.200000  0.761169
# 21  Manchester United    Anthony Martial  43.200000  113.280002  0.610119
# 22  Manchester United    Anthony Martial  43.920001  109.919998  0.045762
# 23  Manchester United       Daniel James  42.160001  115.080002  0.634174
# 24        Southampton  James Ward-Prowse  37.600000   87.360004  0.016577
# 25        Southampton  James Ward-Prowse  45.360001   98.400000  0.158009
# 26        Southampton       Jan Bednarek  39.200000    6.240000  0.000000
# 27        Southampton          Che Adams  41.920001  105.960004  0.333306
#
#          result         xx         yy
# 0   MissedShots  65.300003  75.400002
# 1   BlockedShot  55.200001  87.800003
# 2     SavedShot  71.699997  78.500000
# 3          Goal  47.500000  96.800003
# 4          Goal  50.000000  90.800003
# 5     SavedShot  69.599998  79.300003
# 6     SavedShot  67.500000  80.000000
# 7   MissedShots  44.500000  80.900002
# 8          Goal  49.099998  91.599998
# 9   BlockedShot  70.500000  81.599998
# 10  BlockedShot  61.599998  93.599998
# 11    SavedShot  64.900002  82.500000
# 12  BlockedShot  51.500000  80.300003
# 13  BlockedShot  60.400002  80.500000
# 14         Goal  40.099998  97.599998
# 15    SavedShot  31.000000  92.199997
# 16         Goal  45.099998  75.400002
# 17  MissedShots  69.900002  87.199997
# 18  MissedShots  65.099998  85.599998
# 19    SavedShot  29.900000  83.900002
# 20         Goal  50.000000  88.500000
# 21         Goal  54.000000  94.400002
# 22  MissedShots  54.900002  91.599998
# 23         Goal  52.700001  95.900002
# 24  MissedShots  47.000000  72.800003
# 25    SavedShot  56.700001  82.000000
# 26      OwnGoal  49.000000   5.200000
# 27  MissedShots  52.400002  88.300003

# %%
#select Man Utd shots and SOT's own goals only
manutdshots = shots[(shots.team=='Manchester United')].reset_index()
manutdshots
# Out:
#     index               team             player          x           y  \
# 0       0  Manchester United               Fred  52.240002   90.480002
# 1       1  Manchester United    Mason Greenwood  44.160001  105.360004
# 2       2  Manchester United    Marcus Rashford  57.359998   94.200000
# 3       3  Manchester United  Aaron Wan-Bissaka  38.000000  116.160004
# 4       4  Manchester United    Marcus Rashford  40.000000  108.960004
# 5       5  Manchester United    Bruno Fernandes  55.679999   95.160004
# 6       6  Manchester United          Luke Shaw  54.000000   96.000000
# 7       7  Manchester United    Scott McTominay  35.600000   97.080002
# 8       8  Manchester United     Edinson Cavani  39.279999  109.919998
# 9       9  Manchester United    Bruno Fernandes  56.400000   97.919998
# 10     10  Manchester United    Anthony Martial  49.279999  112.319998
# 11     11  Manchester United    Bruno Fernandes  51.920001   99.000000
# 12     12  Manchester United    Bruno Fernandes  41.200000   96.360004
# 13     13  Manchester United               Fred  48.320001   96.600000
# 14     14  Manchester United    Anthony Martial  32.079999  117.119998
# 15     15  Manchester United    Mason Greenwood  24.800000  110.639996
# 16     16  Manchester United    Scott McTominay  36.079999   90.480002
# 17     17  Manchester United    Anthony Martial  55.920001  104.639996
# 18     18  Manchester United    Bruno Fernandes  52.079999  102.719998
# 19     19  Manchester United    Mason Greenwood  23.920000  100.680002
# 20     20  Manchester United    Bruno Fernandes  40.000000  106.200000
# 21     21  Manchester United    Anthony Martial  43.200000  113.280002
# 22     22  Manchester United    Anthony Martial  43.920001  109.919998
# 23     23  Manchester United       Daniel James  42.160001  115.080002
#
#           xG       result         xx         yy
# 0   0.017538  MissedShots  65.300003  75.400002
# 1   0.113812  BlockedShot  55.200001  87.800003
# 2   0.018009    SavedShot  71.699997  78.500000
# 3   0.615185         Goal  47.500000  96.800003
# 4   0.473977         Goal  50.000000  90.800003
# 5   0.020623    SavedShot  69.599998  79.300003
# 6   0.019086    SavedShot  67.500000  80.000000
# 7   0.066525  MissedShots  44.500000  80.900002
# 8   0.382064         Goal  49.099998  91.599998
# 9   0.075360  BlockedShot  70.500000  81.599998
# 10  0.122666  BlockedShot  61.599998  93.599998
# 11  0.051032    SavedShot  64.900002  82.500000
# 12  0.046692  BlockedShot  51.500000  80.300003
# 13  0.031019  BlockedShot  60.400002  80.500000
# 14  0.352162         Goal  40.099998  97.599998
# 15  0.082893    SavedShot  31.000000  92.199997
# 16  0.017095         Goal  45.099998  75.400002
# 17  0.346995  MissedShots  69.900002  87.199997
# 18  0.073985  MissedShots  65.099998  85.599998
# 19  0.055975    SavedShot  29.900000  83.900002
# 20  0.761169         Goal  50.000000  88.500000
# 21  0.610119         Goal  54.000000  94.400002
# 22  0.045762  MissedShots  54.900002  91.599998
# 23  0.634174         Goal  52.700001  95.900002

# %%
#set figure and axes
fig, ax = plt.subplots(figsize=(13,8.5))
fig.set_facecolor('#253d2d')
ax.patch.set_facecolor('#253d2d')

#create vertical pitch
pitch = VerticalPitch(pitch_type='statsbomb',pitch_color='#22312b', line_color='#c7d5cc', figsize=(13, 8), tight_layout=True, constrained_layout=False, half=True)

pitch.draw(ax=ax)

#def plotShotMap():
for j in range (len(manutdshots['x'])):
    if manutdshots['result'][j] == 'Goal':
        sp = pitch.scatter(manutdshots['y'][j],manutdshots['x'][j], s=manutdshots['xG'][j]*900,c='#00ff00',alpha=.7,ax=ax)
    else:
        sp = pitch.scatter(manutdshots['y'][j],manutdshots['x'][j], s=manutdshots['xG'][j]*900,c='#ea6969',alpha=.7, ax=ax)

default = 'w'

#set title
s = '<Man United Shot Chart vs Southampton>\n<EPL 2020/21>\n<Goals>  <Missed>'
fig_text(x=0.37, y=0.95,
              fontsize=18,
              ha='center', va='center',
              s=s,
              highlight_textprops=[{"color": default},
                                   {"color": default},
                                   {"color": '#00ff00'},
                                   {"color": '#ea6969'}],
              fontname='Roboto',
              ax=ax)

s1 = '<Total Shots: {}>\n<Goals: 9>\n<Conversion Rate: {:.2f}%>'
ax_text(x=50, y=77,
              fontsize=14,
              ha='center', va='center',
              s=s1.format(len(manutdshots['x']), 9/len(manutdshots['x'])*100),
              highlight_textprops=[{"color": default},
                                   {"color": '#00ff00'},
                                   {"color": '#00ccff'}],
              fontname='Roboto',
              ax=ax)

#add Unietd logo
unitedlogo = plt.imread('manunited_logo.png')
imagebox = OffsetImage(unitedlogo, zoom=.05)

xy = [25,68]

ab = AnnotationBbox(imagebox,xy, boxcoords='offset points',frameon=False)
ax.add_artist(ab)

fig.text(.20,.1,"@marcwontweet / Data obtained via Understat",fontstyle='italic',fontsize=11,fontfamily='Roboto',color=default)

#save plotted figure as png
plt.savefig('MUNSOTshotmap.png',dpi=300,bbox_inches = 'tight',facecolor='#22312b')
# Out:
# findfont: Font family ['Roboto'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Roboto'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Roboto'] not found. Falling back to DejaVu Sans.
