# %%
#import required modules and packages
from statsbombpy import sb
import json
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mplsoccer import Pitch, VerticalPitch

# %%
#set default text colour
text_color = 'w'

# %%
#select World Cup 2018 matches data from stastbomb API 
sb.matches(competition_id=43,season_id=3)
# Out:
# credentials were not supplied. open data access only
#     match_id  match_date      kick_off                     competition season  \
# 0       7581  2018-07-01  20:00:00.000  International - FIFA World Cup   2018
# 1       7549  2018-06-22  17:00:00.000  International - FIFA World Cup   2018
# 2       7555  2018-06-24  20:00:00.000  International - FIFA World Cup   2018
# 3       7529  2018-06-16  21:00:00.000  International - FIFA World Cup   2018
# 4       7548  2018-06-22  14:00:00.000  International - FIFA World Cup   2018
# ..       ...         ...           ...                             ...    ...
# 59      8657  2018-07-14  16:00:00.000  International - FIFA World Cup   2018
# 60      7540  2018-06-19  20:00:00.000  International - FIFA World Cup   2018
# 61      7551  2018-06-23  20:00:00.000  International - FIFA World Cup   2018
# 62      7550  2018-06-22  20:00:00.000  International - FIFA World Cup   2018
# 63      7537  2018-06-18  20:00:00.000  International - FIFA World Cup   2018
#
#    home_team    away_team  home_score  away_score match_status  \
# 0    Croatia      Denmark           1           1    available
# 1    Nigeria      Iceland           2           0    available
# 2     Poland     Colombia           0           3    available
# 3    Croatia      Nigeria           2           0    available
# 4     Brazil   Costa Rica           2           0    available
# ..       ...          ...         ...         ...          ...
# 59   Belgium      England           2           0    available
# 60    Russia        Egypt           3           1    available
# 61   Germany       Sweden           2           1    available
# 62    Serbia  Switzerland           1           2    available
# 63   Tunisia      England           1           2    available
#
#    match_status_360      last_updated last_updated_360  match_week  \
# 0       unscheduled  2020-07-29T05:00             None           4
# 1       unscheduled  2020-07-29T05:00             None           2
# 2       unscheduled  2020-07-29T05:00             None           2
# 3       unscheduled  2020-07-29T05:00             None           1
# 4       unscheduled  2020-07-29T05:00             None           2
# ..              ...               ...              ...         ...
# 59      unscheduled  2020-07-29T05:00             None           7
# 60      unscheduled  2020-07-29T05:00             None           2
# 61      unscheduled  2020-07-29T05:00             None           2
# 62      unscheduled  2020-07-29T05:00             None           2
# 63      unscheduled  2020-07-29T05:00             None           1
#
#    competition_stage                    stadium       referee data_version  \
# 0        Round of 16    Stadion Nizhny Novgorod     N. Pitana        1.0.2
# 1        Group Stage            Volgograd Arena     M. Conger        1.0.2
# 2        Group Stage      Kazan' Arena (Kazan')      C. Ramos        1.0.2
# 3        Group Stage        Stadion Kaliningrad  Sandro Ricci        1.0.2
# 4        Group Stage   Saint-Petersburg Stadium    B. Kuipers        1.0.2
# ..               ...                        ...           ...          ...
# 59   3rd Place Final   Saint-Petersburg Stadium    A. Faghani        1.0.2
# 60       Group Stage   Saint-Petersburg Stadium    E. Cáceres        1.0.2
# 61       Group Stage  Olimpiyskiy Stadion Fisht  S. Marciniak        1.0.2
# 62       Group Stage        Stadion Kaliningrad      F. Brych        1.0.2
# 63       Group Stage            Volgograd Arena     W. Roldán        1.0.2
#
#    shot_fidelity_version xy_fidelity_version
# 0                   None                None
# 1                   None                None
# 2                   None                None
# 3                   None                None
# 4                   None                None
# ..                   ...                 ...
# 59                  None                None
# 60                  None                None
# 61                  None                None
# 62                  None                None
# 63                  None                None
#
# [64 rows x 20 columns]

# %%
#select event data of desired match (Germnay vs Sweden)
events = sb.events(match_id = 7551)
events.head()
# Out:
# credentials were not supplied. open data access only
#   50_50 ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 0   NaN                  NaN                            NaN              NaN
# 1   NaN                  NaN                            NaN              NaN
# 2   NaN                  NaN                            NaN              NaN
# 3   NaN                  NaN                            NaN              NaN
# 4   NaN                  NaN                            NaN              NaN
#
#   block_offensive carry_end_location clearance_aerial_won counterpress  \
# 0             NaN                NaN                  NaN          NaN
# 1             NaN                NaN                  NaN          NaN
# 2             NaN                NaN                  NaN          NaN
# 3             NaN                NaN                  NaN          NaN
# 4             NaN                NaN                  NaN          NaN
#
#   dribble_nutmeg dribble_outcome  ... shot_statsbomb_xg shot_technique  \
# 0            NaN             NaN  ...               NaN            NaN
# 1            NaN             NaN  ...               NaN            NaN
# 2            NaN             NaN  ...               NaN            NaN
# 3            NaN             NaN  ...               NaN            NaN
# 4            NaN             NaN  ...               NaN            NaN
#
#    shot_type substitution_outcome substitution_replacement  \
# 0        NaN                  NaN                      NaN
# 1        NaN                  NaN                      NaN
# 2        NaN                  NaN                      NaN
# 3        NaN                  NaN                      NaN
# 4        NaN                  NaN                      NaN
#
#                                              tactics     team     timestamp  \
# 0  {'formation': 4321, 'lineup': [{'player': {'id...  Germany  00:00:00.000
# 1  {'formation': 442, 'lineup': [{'player': {'id'...   Sweden  00:00:00.000
# 2                                                NaN  Germany  00:00:00.000
# 3                                                NaN   Sweden  00:00:00.000
# 4                                                NaN   Sweden  00:00:00.000
#
#           type under_pressure
# 0  Starting XI            NaN
# 1  Starting XI            NaN
# 2   Half Start            NaN
# 3   Half Start            NaN
# 4   Half Start            NaN
#
# [5 rows x 79 columns]

# %%
#observe available columns
events.columns
# Out:
# Index(['50_50', 'ball_receipt_outcome', 'ball_recovery_recovery_failure',
#        'block_deflection', 'block_offensive', 'carry_end_location',
#        'clearance_aerial_won', 'counterpress', 'dribble_nutmeg',
#        'dribble_outcome', 'duel_outcome', 'duel_type', 'duration',
#        'foul_committed_advantage', 'foul_committed_card',
#        'foul_committed_offensive', 'foul_committed_type', 'foul_won_advantage',
#        'foul_won_defensive', 'goalkeeper_body_part', 'goalkeeper_end_location',
#        'goalkeeper_outcome', 'goalkeeper_position', 'goalkeeper_technique',
#        'goalkeeper_type', 'id', 'index', 'injury_stoppage_in_chain',
#        'interception_outcome', 'location', 'match_id', 'minute',
#        'miscontrol_aerial_won', 'pass_aerial_won', 'pass_angle',
#        'pass_assisted_shot_id', 'pass_backheel', 'pass_body_part',
#        'pass_cross', 'pass_cut_back', 'pass_deflected', 'pass_end_location',
#        'pass_goal_assist', 'pass_height', 'pass_length', 'pass_outcome',
#        'pass_recipient', 'pass_shot_assist', 'pass_switch', 'pass_technique',
#        'pass_through_ball', 'pass_type', 'period', 'play_pattern', 'player',
#        'position', 'possession', 'possession_team', 'related_events', 'second',
#        'shot_aerial_won', 'shot_body_part', 'shot_deflected',
#        'shot_end_location', 'shot_first_time', 'shot_freeze_frame',
#        'shot_key_pass_id', 'shot_one_on_one', 'shot_outcome',
#        'shot_statsbomb_xg', 'shot_technique', 'shot_type',
#        'substitution_outcome', 'substitution_replacement', 'tactics', 'team',
#        'timestamp', 'type', 'under_pressure'],
#       dtype='object')

# %%
#Select desired columns (Shots taken by Germany throughout the match)
events = events[['team','player','type','minute','location','shot_type','shot_outcome']]
shotevents = events[events['type']=='Shot'].reset_index()
gershots = shotevents[shotevents['team']=='Germany'].reset_index()
gershots.head()
# Out:
#    level_0  index     team          player  type  minute       location  \
# 0        0   3209  Germany  Julian Draxler  Shot       2  [113.0, 42.0]
# 1        1   3210  Germany    Jonas Hector  Shot       2  [104.0, 40.0]
# 2        3   3212  Germany  Jérôme Boateng  Shot      15   [97.0, 53.0]
# 3        5   3214  Germany  Sebastian Rudy  Shot      18   [92.0, 42.0]
# 4        7   3216  Germany  İlkay Gündoğan  Shot      38   [94.0, 28.0]
#
#    shot_type shot_outcome
# 0  Open Play      Blocked
# 1  Open Play      Blocked
# 2  Open Play      Blocked
# 3  Open Play      Blocked
# 4  Open Play        Saved

# %%
#Splitting 'location' into two 'x' and 'y' colunmns
gershots = gershots.join(pd.DataFrame(gershots.pop('location').tolist(), index=gershots.index, columns=["x", "y"]))
gershots['x'] = gershots['x']*.8
gershots['x'] = gershots['x']*1.2

gershots
# Out:
#     level_0  index     team              player  type  minute  shot_type  \
# 0         0   3209  Germany      Julian Draxler  Shot       2  Open Play
# 1         1   3210  Germany        Jonas Hector  Shot       2  Open Play
# 2         3   3212  Germany      Jérôme Boateng  Shot      15  Open Play
# 3         5   3214  Germany      Sebastian Rudy  Shot      18  Open Play
# 4         7   3216  Germany      İlkay Gündoğan  Shot      38  Open Play
# 5         8   3217  Germany      Jérôme Boateng  Shot      44  Open Play
# 6        10   3219  Germany          Marco Reus  Shot      47  Open Play
# 7        11   3220  Germany          Toni Kroos  Shot      48  Open Play
# 8        12   3221  Germany       Thomas Müller  Shot      50  Open Play
# 9        13   3222  Germany        Jonas Hector  Shot      55  Open Play
# 10       14   3223  Germany          Toni Kroos  Shot      62  Open Play
# 11       15   3224  Germany          Toni Kroos  Shot      64  Open Play
# 12       16   3225  Germany          Marco Reus  Shot      72  Open Play
# 13       17   3226  Germany          Toni Kroos  Shot      72  Open Play
# 14       19   3228  Germany         Timo Werner  Shot      80  Open Play
# 15       21   3230  Germany  Mario Gómez García  Shot      87  Open Play
# 16       22   3231  Germany       Julian Brandt  Shot      91  Open Play
# 17       24   3233  Germany          Toni Kroos  Shot      94  Open Play
#
#    shot_outcome       x     y
# 0       Blocked  108.48  42.0
# 1       Blocked   99.84  40.0
# 2       Blocked   93.12  53.0
# 3       Blocked   88.32  42.0
# 4         Saved   90.24  28.0
# 5         Off T   92.16  62.0
# 6          Goal  107.52  40.0
# 7       Blocked   96.96  29.0
# 8         Off T  106.56  54.0
# 9         Saved  107.52  30.0
# 10      Blocked  100.80  29.0
# 11      Blocked   89.28  38.0
# 12      Blocked  101.76  22.0
# 13      Wayward  100.80  26.0
# 14        Off T  104.64  49.0
# 15        Saved  106.56  40.0
# 16         Post   96.96  46.0
# 17         Goal  106.56  20.0

# %%
#set figure and axes
fig, ax = plt.subplots(figsize=(13,8.5))
fig.set_facecolor('#253d2d')
ax.patch.set_facecolor('#253d2d')

#create vertical pitch
pitch = VerticalPitch(pitch_type='statsbomb',pitch_color='#22312b', line_color='#c7d5cc', figsize=(13, 8), tight_layout=True, half=True)

pitch.draw(ax=ax)

#plotting the points (shot location)
sc= pitch.scatter(gershots.x,gershots.y, s=100,c='#ea6969',alpha=.7, ax=ax)

#set title
s='Germany Shot Chart vs Sweden\n World Cup 2018'
plt.figtext(s=s,x=.49,y=.9,fontfamily='Arial',fontsize=24,color=text_color,horizontalalignment='center')

total_shots = len(gershots)
#set wordings on the axes
plt.figtext(s=f'Total Shots: {total_shots}',x=.32, y =.37, fontsize=14,fontfamily='Arial',color=text_color)
plt.figtext(s=f'Goals: 1',x=.32, y =.30, fontsize=14,fontfamily='Arial',color=text_color)

#save plotted figure as png
plt.savefig('GERvsSWEshotmap.png',dpi=300,bbox_inches = 'tight',facecolor='#22312b')
